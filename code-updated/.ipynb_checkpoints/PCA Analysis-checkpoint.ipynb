# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#Loading all the data files
data3 = pd.read_csv('/Users/chaarvibansal/Desktop/analysis-mutations/data-updated/covid_kmer_3.csv')
data5 = pd.read_csv('/Users/chaarvibansal/Desktop/analysis-mutations/data-updated/covid_kmer_5.csv')
data7 = pd.read_csv('/Users/chaarvibansal/Desktop/analysis-mutations/data-updated/covid_kmer_7.csv')

# %% [markdown]
# ## 10 Component Analysis

# %%
def pca_analysis(data):
    del data['Unnamed: 0']
    X = data.drop(['target'], axis = 1)
    pca = PCA(n_components=10)
    principalComponents = pca.fit_transform(X)
    principal_df = pd.DataFrame(data = principalComponents
                 , columns = ['principal component 1', 'principal component 2','principal component 3','principal component 4',
                             'principal component 5','principal component 6','principal component 7','principal component 8',
                             'principal component 9','principal component 10'])
    print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
    n_components = 10
    total_var = pca.explained_variance_ratio_.sum() * 100
    fig = px.scatter_matrix(principalComponents,dimensions=range(n_components), labels=data,title=f'Total Explained Variance: {total_var:.2f}%')
    fig.update_traces(diagonal_visible=False)
    return principal_df

# %%
principal_df_3 = n_component_analysis(data3)
# Out:
# Explained variation per principal component: [9.83372005e-01 4.00057963e-03 2.10619633e-03 1.53881468e-03
#  1.15857751e-03 9.31682794e-04 8.08676615e-04 6.32223393e-04
#  5.45656290e-04 5.19107932e-04]
# ...

# %%
principal_df_5 = n_component_analysis(data5)
# Out:
# Explained variation per principal component: [0.82237687 0.03502154 0.01171204 0.01006973 0.00954668 0.00811425
#  0.00705262 0.00661759 0.00566046 0.00497752]
# ...

# %%
principal_df_7 =n_component_analysis(data7)
# Out:
# Explained variation per principal component: [0.35600309 0.11060399 0.04498319 0.03619576 0.03288782 0.02983702
#  0.0262752  0.02347596 0.0183628  0.01695947]
# ...
